# %%
import requests

# %%
city = input('input the city name ')
print(city)
# Out:
# input the city name hyderabad
# hyderabad

# %%
#Display the message!
print('Displaying Weater report for: ' + city)
# Out:
# Displaying Weater report for: hyderabad

# %%
#fetch the weater details
url = 'https://wttr.in/{}'.format(city)
res = requests.get(url)

# %%
#display the result!
print(res.text)
# Out:
# Weather report: hyderabad
#
#                 Haze
#    _ - _ - _ -  +73(77) °F
#     _ - _ - _   ↓ 0 mph
#    _ - _ - _ -  3 mi
#                 0.0 in
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Thu 23 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │  _`/"".-.     Light rain sho…│  _`/"".-.     Light rain sho…│  _`/"".-.     Light rain sho…│  _`/"".-.     Patchy rain po…│
# │   ,\_(   ).   +77(80) °F     │   ,\_(   ).   +82(87) °F     │   ,\_(   ).   +75(78) °F     │   ,\_(   ).   +75(78) °F     │
# │    /(___(__)  ↘ 6-8 mph      │    /(___(__)  → 8-9 mph      │    /(___(__)  → 6-9 mph      │    /(___(__)  → 5-9 mph      │
# │      ‘ ‘ ‘ ‘  6 mi           │      ‘ ‘ ‘ ‘  6 mi           │      ‘ ‘ ‘ ‘  6 mi           │      ‘ ‘ ‘ ‘  6 mi           │
# │     ‘ ‘ ‘ ‘   0.0 in | 83%   │     ‘ ‘ ‘ ‘   0.0 in | 79%   │     ‘ ‘ ‘ ‘   0.0 in | 72%   │     ‘ ‘ ‘ ‘   0.0 in | 83%   │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Fri 24 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │               Cloudy         │               Cloudy         │  _`/"".-.     Patchy rain po…│    \  /       Partly cloudy  │
# │      .--.     +78(82) °F     │      .--.     +86(91) °F     │   ,\_(   ).   +77(80) °F     │  _ /"".-.     +75(78) °F     │
# │   .-(    ).   → 8-9 mph      │   .-(    ).   ↘ 6-8 mph      │    /(___(__)  ↗ 6-11 mph     │    \_(   ).   ↗ 6-12 mph     │
# │  (___.__)__)  6 mi           │  (___.__)__)  6 mi           │      ‘ ‘ ‘ ‘  5 mi           │    /(___(__)  6 mi           │
# │               0.0 in | 0%    │               0.0 in | 0%    │     ‘ ‘ ‘ ‘   0.0 in | 75%   │               0.0 in | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Sat 25 Sep ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │    \  /       Partly cloudy  │  _`/"".-.     Light rain sho…│  _`/"".-.     Patchy rain po…│    \  /       Partly cloudy  │
# │  _ /"".-.     +78(84) °F     │   ,\_(   ).   +84(91) °F     │   ,\_(   ).   +77(80) °F     │  _ /"".-.     +75(78) °F     │
# │    \_(   ).   → 10-12 mph    │    /(___(__)  → 11-13 mph    │    /(___(__)  → 7-11 mph     │    \_(   ).   ↘ 7-11 mph     │
# │    /(___(__)  6 mi           │      ‘ ‘ ‘ ‘  6 mi           │      ‘ ‘ ‘ ‘  6 mi           │    /(___(__)  6 mi           │
# │               0.0 in | 0%    │     ‘ ‘ ‘ ‘   0.0 in | 63%   │     ‘ ‘ ‘ ‘   0.0 in | 50%   │               0.0 in | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
# Location: Hyderabad, Medak, Telangana, India [17.3616227,78.4747305]
#
# Follow @igor_chubin for wttr.in updates
